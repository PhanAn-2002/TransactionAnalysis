# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Xử lý data

# %%
customer_info = pd.read_excel(r"C:\Users\Admin\khoa4\test2\DA_TEST_1\customers (UK).xlsx", sheet_name=0)
customer_info
# Out:
#         ID              FirstName                LastName  \
# 0      0.0     V0.296680287495188      L0.104646531512644
# 1      1.0     D0.793097101838541    Law0.141693355411763
# 2      2.0   Ker0.141418247925814     Ng0.753960335680345
# 3      3.0   Fik0.950054552966336      F0.590961171612745
# 4      4.0  Iona0.294287981536498   Ison0.826191754811968
# ..     ...                    ...                     ...
# 765  765.0    Ya0.945566148422846     Lo0.214781069325519
# 766  766.0   Yoo0.331072249620266    Low0.870500054610635
# 767  767.0    Za0.957577858135873  Thoma0.729674423009536
# 768  768.0     Y0.286774649994125   Aung0.752567424443609
# 769  769.0    Yu0.868816854574661   Tuck0.670377392941702
#
#                  Country DateJoined Gender   Birthday Newsletter
# 0            FR - France 2015-12-18    NaN 1968-02-03          N
# 1          GER - Germany 2015-12-21      M 2009-10-06          Y
# 2            FR - France 2015-12-22      F 1990-08-04          Y
# ...

# %%
items = pd.read_excel(r"C:\Users\Admin\khoa4\test2\DA_TEST_1\customers (UK).xlsx", sheet_name=1)

items
# Out:
#         ItemID                      Product                   Brand  \
# 0          1.0   032irview0.686128260621012        Ki)D3jDmA,RIP68X
# 1          2.0   070ttream0.518887735674677        GO4582ey<S!+k1VE
# 2          3.0   070htream0.333307794468401        G.Kb^jz*soY!(-4Q
# 3          4.0   100Grseys0.271522111052549        Dr|vm[-5p~56Y\mk
# 4          5.0   100[nside0.645837365801341        Dr|vm[-5p~56Y\mk
# ...        ...                          ...                     ...
# 17884  17885.0   zarzmodel0.705343660670698  Zah<@kD,N[_x007f_Vo]vf
# 17885  17886.0   zelQailer0.599088919243258        Nia_TfHUVDtT>6-s
# 17886  17887.0   zenyation0.980382120595891        Chbm3nL;wgcU<S(y
# 17887  17888.0   zenvition0.646980947183814        Ac8IJsKH,4xtY.Tk
# 17888  17889.0  zipBlease0.0313238391182887        Zi;R(P$t]{$);Ze!
#
#        SellPrice  CostPrice
# 0          943.0      359.0
# 1          717.0      207.0
# 2          739.0      199.0
# 3          532.0      262.0
# ...

# %%
customer_trans = pd.read_excel(r"C:\Users\Admin\khoa4\test2\DA_TEST_1\customers (UK).xlsx", sheet_name=2)
customer_trans
# Out:
#        OrderID  CustomerID   ItemID TransactionDate   Channel
# 0          0.0         0.0    352.0      2020-03-21  In Store
# 1          0.0         0.0   3433.0      2020-07-14  In Store
# 2          0.0         0.0  11162.0      2020-08-09  In Store
# 3          0.0         0.0  13011.0      2020-12-07  In Store
# 4          0.0         0.0  13885.0      2020-11-08  In Store
# ...        ...         ...      ...             ...       ...
# 25208   8361.0       769.0  10053.0      2020-12-19  In Store
# 25209   8361.0       769.0  13162.0      2020-02-04  In Store
# 25210   8362.0       769.0   8727.0      2020-11-18  In Store
# 25211   8362.0       769.0  13065.0      2020-05-11  In Store
# 25212   8362.0       769.0  13577.0      2020-06-05  In Store
#
# [25213 rows x 5 columns]

# %%
traffic_01 = pd.read_excel(r"C:\Users\Admin\khoa4\test2\DA_TEST_1\Traffic\2020_01.xlsx",sheet_name=0)
traffic_02 = pd.read_excel(r"C:\Users\Admin\khoa4\test2\DA_TEST_1\Traffic\2020_02.xlsx",sheet_name=0)
traffic_03 = pd.read_excel(r"C:\Users\Admin\khoa4\test2\DA_TEST_1\Traffic\2020_03.xlsx",sheet_name=0)
traffic_04 = pd.read_excel(r"C:\Users\Admin\khoa4\test2\DA_TEST_1\Traffic\2020_04.xlsx",sheet_name=0)
traffic_05 = pd.read_excel(r"C:\Users\Admin\khoa4\test2\DA_TEST_1\Traffic\2020_05.xlsx",sheet_name=0)
traffic_06 = pd.read_excel(r"C:\Users\Admin\khoa4\test2\DA_TEST_1\Traffic\2020_06.xlsx",sheet_name=0)
traffic_07 = pd.read_excel(r"C:\Users\Admin\khoa4\test2\DA_TEST_1\Traffic\2020_07.xlsx",sheet_name=0)
traffic_08 = pd.read_excel(r"C:\Users\Admin\khoa4\test2\DA_TEST_1\Traffic\2020_08.xlsx",sheet_name=0)
traffic_09 = pd.read_excel(r"C:\Users\Admin\khoa4\test2\DA_TEST_1\Traffic\2020_09.xlsx",sheet_name=0)
traffic_10 = pd.read_excel(r"C:\Users\Admin\khoa4\test2\DA_TEST_1\Traffic\2020_10.xlsx",sheet_name=0)
traffic_11 = pd.read_excel(r"C:\Users\Admin\khoa4\test2\DA_TEST_1\Traffic\2020_11.xlsx",sheet_name=0)
traffic_12 = pd.read_excel(r"C:\Users\Admin\khoa4\test2\DA_TEST_1\Traffic\2020_12.xlsx",sheet_name=0)

# %%
traffic = pd.concat([traffic_01, traffic_02,traffic_03,traffic_04,traffic_05,\
                     traffic_06,traffic_07,traffic_08,traffic_09,traffic_10,traffic_11,traffic_12],\
                    ignore_index=True)
traffic
# Out:
#                                    Page URL   users  uniquePageviews  \
# 0        /2020/1/032irview0.686128260621012  5669.2           5777.8
# 1        /2020/1/070ttream0.518887735674677   359.8            370.4
# 2        /2020/1/070htream0.333307794468401   587.6            614.2
# 3        /2020/1/100Grseys0.271522111052549  1284.0           1308.6
# 4        /2020/1/100[nside0.645837365801341  1846.0           1880.8
# ...                                     ...     ...              ...
# 17884     /2020/12/yinfbowls0.6558670149224   130.0            133.2
# 17885  /2020/12/yosolease0.0455049365834417   314.6            325.6
# 17886   /2020/12/you^-info0.127669879156147  1419.6           1448.4
# 17887   /2020/12/youe-info0.729842478879044   483.8            487.6
# 17888   /2020/12/zahJuseum0.120647638596675   823.2            837.6
#
#        pageviews                   Brand Posted On (DD/MM/YYYY)
# 0         6286.4        Ki)D3jDmA,RIP68X    2020-01-10 16:56:13
# ...

# %%
traffic['Page URL'].iloc[0].split('/')[-1]
# Out:
# '032irview0.686128260621012'

# %%
# Tách Product trong Page URL
traffic['Product'] = range(len(traffic['Page URL']))
for i in range(len(traffic['Page URL'])):
    traffic['Product'][i] = traffic['Page URL'].iloc[i].split('/')[-1]
traffic
# Out:
#                                    Page URL   users  uniquePageviews  \
# 0        /2020/1/032irview0.686128260621012  5669.2           5777.8
# 1        /2020/1/070ttream0.518887735674677   359.8            370.4
# 2        /2020/1/070htream0.333307794468401   587.6            614.2
# 3        /2020/1/100Grseys0.271522111052549  1284.0           1308.6
# 4        /2020/1/100[nside0.645837365801341  1846.0           1880.8
# ...                                     ...     ...              ...
# 17884     /2020/12/yinfbowls0.6558670149224   130.0            133.2
# 17885  /2020/12/yosolease0.0455049365834417   314.6            325.6
# 17886   /2020/12/you^-info0.127669879156147  1419.6           1448.4
# 17887   /2020/12/youe-info0.729842478879044   483.8            487.6
# 17888   /2020/12/zahJuseum0.120647638596675   823.2            837.6
#
#        pageviews                   Brand Posted On (DD/MM/YYYY)  \
# 0         6286.4        Ki)D3jDmA,RIP68X    2020-01-10 16:56:13
# ...

# %%
traffic.sort_values('Posted On (DD/MM/YYYY)', ascending=True, inplace=True, ignore_index=True)

# %%
traffic
# Out:
#                                   Page URL   users  uniquePageviews  \
# 0       /2020/1/vanBip-on0.100834672919284  1034.8           1048.4
# 1       /2020/1/fujBdence0.385183712192661  4097.8           4142.6
# 2       /2020/1/baiXpsule0.236876019278184   642.6            653.8
# 3       /2020/1/artjriner0.183950395687591  3413.0           3469.6
# 4       /2020/1/appMn-usd0.284138838758011  1447.0           1465.6
# ...                                    ...     ...              ...
# 17884  /2020/12/nicKailer0.757067004243723   369.4            375.8
# 17885  /2020/12/j-crvideo0.411325399883596   408.6            419.0
# 17886  /2020/12/asak-info0.272774402976534   286.8            291.8
# 17887  /2020/12/andx-info0.805313550947187  1430.4           1457.8
# 17888  /2020/12/kantalbum0.420265088159373   728.4            741.6
#
#        pageviews             Brand Posted On (DD/MM/YYYY)  \
# 0         1134.4  Vag9"-Z=gN30ND@[    2020-01-01 01:03:02
# ...

# %%
#merge data

data = customer_trans.merge(customer_info,how='inner',left_on='CustomerID', right_on='ID').\
                    merge(items,how='inner',left_on='ItemID', right_on='ItemID')
#.\merge(traffic,how='inner',left_on='Product', right_on='Product')

# %%
data.drop('ID', inplace=True, axis=1)
data
# Out:
#        OrderID  CustomerID   ItemID TransactionDate   Channel  \
# 0          0.0         0.0    352.0      2020-03-21  In Store
# 1        637.0        57.0    352.0      2020-03-15  In Store
# 2          0.0         0.0   3433.0      2020-07-14  In Store
# 3       1840.0       167.0   3433.0      2020-05-16  In Store
# 4       3386.0       307.0   3433.0      2020-04-23  In Store
# ...        ...         ...      ...             ...       ...
# 25208   8358.0       769.0  15836.0      2020-10-14  In Store
# 25209   8359.0       769.0   5847.0      2020-05-27    Online
# 25210   8362.0       769.0   8727.0      2020-11-18  In Store
# 25211   8362.0       769.0  13065.0      2020-05-11  In Store
# 25212   8362.0       769.0  13577.0      2020-06-05  In Store
#
#                    FirstName                LastName              Country  \
# 0         V0.296680287495188      L0.104646531512644          FR - France
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25213 entries, 0 to 25212
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   OrderID          25213 non-null  float64
#  1   CustomerID       25213 non-null  float64
#  2   ItemID           25213 non-null  float64
#  3   TransactionDate  25213 non-null  datetime64[ns]
#  4   Channel          25213 non-null  object
#  5   FirstName        25213 non-null  object
#  6   LastName         25213 non-null  object
#  7   Country          25213 non-null  object
#  8   DateJoined       25213 non-null  datetime64[ns]
#  9   Gender           16892 non-null  object
#  10  Birthday         25213 non-null  datetime64[ns]
#  11  Newsletter       25213 non-null  object
#  12  Product          25213 non-null  object
#  13  Brand            25213 non-null  object
#  14  SellPrice        25213 non-null  float64
#  15  CostPrice        25213 non-null  float64
# ...

# %% [markdown]
# ## 1. Website traffic có ảnh hưởng đến doanh thu không ?

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### users, uniquePageviews, pageviews by Date

# %%
fig, ax = plt.subplots(figsize=(12, 6))

ax.plot(traffic['Posted On (DD/MM/YYYY)'],traffic['pageviews'],)


# thêm title, label các trục và source:
plt.suptitle('Pageviews by Date', fontweight='bold', size=14, horizontalalignment='left', x=0.125, y = 1)
plt.xlabel('Date', size=12)
plt.ylabel('pageviews', size=12)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 6))

ax.plot(traffic['Posted On (DD/MM/YYYY)'],traffic['uniquePageviews'],)


# thêm title, label các trục và source:
plt.suptitle('UniquePageviews by Date', fontweight='bold', size=14, horizontalalignment='left', x=0.125, y = 1)
plt.xlabel('Date', size=12)
plt.ylabel('uniquePageviews', size=12)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 6))

ax.plot(traffic['Posted On (DD/MM/YYYY)'],traffic['users'],)


# thêm title, label các trục và source:
plt.suptitle('Users by Date', fontweight='bold', size=14, horizontalalignment='left', x=0.125, y = 1)
plt.xlabel('Date', size=12)
plt.ylabel('users', size=12)

plt.show()

# %% [markdown]
# ### Doanh thu bán hàng online và tại cửa hàng

# %%
revenus_year = data.groupby('Channel')[['SellPrice']].sum()
revenus_year.loc['Column_Total']= revenus_year.sum(numeric_only=True, axis=0)
revenus_year.reset_index(inplace=True)
revenus_year['change%'] = (revenus_year['SellPrice']/int(revenus_year['SellPrice'].iloc[2:3]))*100
revenus_year
# Out:
#         Channel   SellPrice     change%
# 0      In Store  10222263.0   50.066875
# 1        Online  10194955.0   49.933125
# 2  Column_Total  20417218.0  100.000000

# %% [markdown]
# Tổng doanh thu bán hàng online và in store xấp xỉ 50%, không có nhiều sự khác biệt. Kênh bán hàng online bây giờ cũng rất quan trọng với doanh nghiệp, không thua kém gì so với bán tại cửa hàng.

# %%
summary_trans = data.groupby(["TransactionDate","Channel"]).\
                            agg(total_orders = ('OrderID','nunique'),total_items = ('ItemID','size'), total_revenue = ('SellPrice','sum')).\
                            reset_index()

# %%
summary_trans
# Out:
#     TransactionDate   Channel  total_orders  total_items  total_revenue
# 0        2020-01-01  In Store            30           30        23820.0
# 1        2020-01-01    Online            35           36        32044.0
# 2        2020-01-02  In Store            33           33        24069.0
# 3        2020-01-02    Online            40           40        31612.0
# 4        2020-01-03  In Store            46           46        37118.0
# ..              ...       ...           ...          ...            ...
# 643      2020-12-25    Online            43           43        31365.0
# 644      2020-12-26  In Store            28           28        23072.0
# 645      2020-12-26    Online            39           41        33473.0
# 646      2020-12-27  In Store            45           45        37629.0
# 647      2020-12-27    Online            42           42        34419.0
#
# [648 rows x 5 columns]

# %%
fig, ax = plt.subplots(figsize=(12, 6))

ax.plot(summary_trans[summary_trans["Channel"] == "In Store"].TransactionDate,\
        summary_trans[summary_trans["Channel"] == "In Store"].total_orders, \
       label="In Store")

ax.plot(summary_trans[summary_trans["Channel"] == "Online"].TransactionDate,\
        summary_trans[summary_trans["Channel"] == "Online"].total_orders, \
       label="Online")

plt.legend()
# thêm title, label các trục và source:
plt.suptitle('Total Orders by Date', fontweight='bold', size=14, horizontalalignment='left', x=0.125, y = 1)
plt.xlabel('Transaction Date', size=12)
plt.ylabel('Total Orders', size=12)


plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 6))

ax.plot(summary_trans[summary_trans["Channel"] == "In Store"].TransactionDate,\
        summary_trans[summary_trans["Channel"] == "In Store"].total_items, \
       label="In Store")

ax.plot(summary_trans[summary_trans["Channel"] == "Online"].TransactionDate,\
        summary_trans[summary_trans["Channel"] == "Online"].total_items, \
       label="Online")

plt.legend()
# thêm title, label các trục và source:
plt.suptitle('Total Items by Date', fontweight='bold', size=14, horizontalalignment='left', x=0.125, y = 1)
plt.xlabel('Transaction Date', size=12)
plt.ylabel('Total items', size=12)


plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 6))

ax.plot(summary_trans[summary_trans["Channel"] == "In Store"].TransactionDate,\
        summary_trans[summary_trans["Channel"] == "In Store"].total_revenue, \
       label="In Store")

ax.plot(summary_trans[summary_trans["Channel"] == "Online"].TransactionDate,\
        summary_trans[summary_trans["Channel"] == "Online"].total_revenue, \
       label="Online")

plt.legend()
# thêm title, label các trục và source:
plt.suptitle('Total Revenue by Date', fontweight='bold', size=14, horizontalalignment='left', x=0.125, y = 1)
plt.xlabel('Transaction Date', size=12)
plt.ylabel('Total Revenue', size=12)

plt.show()

# %% [markdown]
# **Kết luận:** không có quá nhiều sự khác biệt về số lượng đơn hàng, số lượng sản phẩm, và doanh thu giữa 2 kênh Online và tại In store

# %%
revenue = data.groupby(["TransactionDate"], as_index=False)\
                        ["SellPrice"]\
                        .agg([np.sum]).reset_index().rename(columns={'sum':'total_revenue'})

# %%
revenue
# Out:
#     TransactionDate  total_revenue
# 0        2020-01-01        55864.0
# 1        2020-01-02        55681.0
# 2        2020-01-03        67753.0
# 3        2020-01-04        64573.0
# 4        2020-01-05        61098.0
# ..              ...            ...
# 319      2020-12-23        61634.0
# 320      2020-12-24        44266.0
# 321      2020-12-25        63062.0
# 322      2020-12-26        56545.0
# 323      2020-12-27        72048.0
#
# [324 rows x 2 columns]

# %%
from datetime import datetime as dt

# %%
traffic['Date'] = traffic['Posted On (DD/MM/YYYY)'].dt.date

# %%
traffic
# Out:
#                                   Page URL   users  uniquePageviews  \
# 0       /2020/1/vanBip-on0.100834672919284  1034.8           1048.4
# 1       /2020/1/fujBdence0.385183712192661  4097.8           4142.6
# 2       /2020/1/baiXpsule0.236876019278184   642.6            653.8
# 3       /2020/1/artjriner0.183950395687591  3413.0           3469.6
# 4       /2020/1/appMn-usd0.284138838758011  1447.0           1465.6
# ...                                    ...     ...              ...
# 17884  /2020/12/nicKailer0.757067004243723   369.4            375.8
# 17885  /2020/12/j-crvideo0.411325399883596   408.6            419.0
# 17886  /2020/12/asak-info0.272774402976534   286.8            291.8
# 17887  /2020/12/andx-info0.805313550947187  1430.4           1457.8
# 17888  /2020/12/kantalbum0.420265088159373   728.4            741.6
#
#        pageviews             Brand Posted On (DD/MM/YYYY)  \
# 0         1134.4  Vag9"-Z=gN30ND@[    2020-01-01 01:03:02
# ...

# %%
summary_traffic = traffic.groupby(["Date"]).\
                            agg(total_users = ('users','sum'), total_uniquePageviews = ('uniquePageviews','sum'), total_pageviews = ('pageviews','sum')).\
                            reset_index()

# %%
summary_traffic
# Out:
#            Date  total_users  total_uniquePageviews  total_pageviews
# 0    2020-01-01      63755.4                64814.8          70353.6
# 1    2020-01-02     111861.4               113640.0         122557.8
# 2    2020-01-03      63749.8                65175.4          71058.0
# 3    2020-01-04      13946.0                14274.6          15349.6
# 4    2020-01-05      47065.0                47856.6          51438.2
# ..          ...          ...                    ...              ...
# 338  2020-12-05      23906.0                24678.8          27024.6
# 339  2020-12-06      25892.8                26517.0          28433.4
# 340  2020-12-07      95081.8                97565.0         105456.0
# 341  2020-12-08     100577.0               105419.6         150902.2
# 342  2020-12-09      48557.4                50617.8          73336.2
#
# [343 rows x 4 columns]

# %%
summary_traffic['Date'] = pd.to_datetime(summary_traffic['Date'])

# %%
revenue_x_traffic = revenue.merge(summary_traffic,how='inner',left_on='TransactionDate', right_on='Date')

# %%
revenue_x_traffic.drop('Date', inplace=True, axis=1)

# %%
revenue_x_traffic
# Out:
#     TransactionDate  total_revenue  total_users  total_uniquePageviews  \
# 0        2020-01-01        55864.0      63755.4                64814.8
# 1        2020-01-02        55681.0     111861.4               113640.0
# 2        2020-01-03        67753.0      63749.8                65175.4
# 3        2020-01-04        64573.0      13946.0                14274.6
# 4        2020-01-05        61098.0      47065.0                47856.6
# ..              ...            ...          ...                    ...
# 300      2020-12-05        55953.0      23906.0                24678.8
# 301      2020-12-06        47406.0      25892.8                26517.0
# 302      2020-12-07        65365.0      95081.8                97565.0
# 303      2020-12-08        67222.0     100577.0               105419.6
# 304      2020-12-09        88832.0      48557.4                50617.8
#
#      total_pageviews
# 0            70353.6
# 1           122557.8
# 2            71058.0
# 3            15349.6
# ...

# %% [markdown]
# ### Check correlation

# %%
import scipy.stats as stats

# %%
fig, ax = plt.subplots(figsize=(12, 6))

ax.scatter(revenue_x_traffic['total_revenue'],revenue_x_traffic['total_users'])

    
plt.xlabel('Total revenue', size=12)
plt.ylabel('Total users', size=12)

plt.show()

# %%
pearson_coef, p_value = stats.pearsonr(revenue_x_traffic['total_revenue'], revenue_x_traffic['total_users'])
print("Correlation Coefficient là", pearson_coef.round(3))
print("Giá trị P-value là ", p_value.round(3))
# Out:
# Correlation Coefficient là 0.076
# Giá trị P-value là  0.184

# %%
fig, ax = plt.subplots(figsize=(12, 6))

ax.scatter(revenue_x_traffic['total_revenue'],revenue_x_traffic['total_uniquePageviews'])
    
plt.xlabel('Total revenue', size=12)
plt.ylabel('Total uniquePageviews', size=12)

plt.show()

# %%
pearson_coef, p_value = stats.pearsonr(revenue_x_traffic['total_revenue'], revenue_x_traffic['total_uniquePageviews'])
print("Correlation Coefficient là", pearson_coef.round(3))
print("Giá trị P-value là ", p_value.round(3))
# Out:
# Correlation Coefficient là 0.076
# Giá trị P-value là  0.188

# %%
fig, ax = plt.subplots(figsize=(12, 6))

ax.scatter(revenue_x_traffic['total_revenue'],revenue_x_traffic['total_pageviews'])
   
plt.xlabel('Total revenue', size=12)
plt.ylabel('Total pageviews', size=12)

plt.show()

# %% [markdown]
# - total_revenue và total_users dường như không tương quan với nhau
# - total_revenue và total_uniquePageviews, total_pageviews cũng vậy

# %% [markdown]
# **Kết luận:** dường như dữ liệu trong website straffic không tác động đến doanh thu

# %% [markdown]
# ## 2. Sản phẩm nào mang lại pageviews và doanh thu

# %%
items_revenue = data.groupby(['Brand','Product']).agg(total_revenue = ('SellPrice','sum'),total_orders=('OrderID','count'),total_customers = ('CustomerID','count'),total_items = ('ItemID','count'))

# %%
items_revenue
# Out:
#                                               total_revenue  total_orders  \
# Brand            Product
# !lMifo~0~N65rM}2 skyK-date0.237469692167954          2715.0             3
# #B_-`aDe`}CVt'!A 18-`lease0.952310074301681           478.0             1
#                  202rvideo0.0198947312483128          392.0             1
#                  6layenter0.832904875099387          1986.0             3
#                  a-cPrants0.941652415797535          1384.0             2
# ...                                                     ...           ...
# ze\yQP9Ju,s(O|>] zel`video0.809705577564763           332.0             1
#                  zelkvideo0.542849205536647          1052.0             2
#                  zeloalbum0.673018009367897          3234.0             3
# Ét2:1))2]qB2`9;^ etua-baby0.472156023137423          1048.0             2
#                  etujation0.0817298363167827         1233.0             1
#
# ...

# %%
items_revenue.describe()
# Out:
#        total_revenue  total_orders  total_customers   total_items
# count   13542.000000  13542.000000     13542.000000  13542.000000
# mean     1507.695909      1.861837         1.861837      1.861837
# std      1096.691381      1.005725         1.005725      1.005725
# min        46.000000      1.000000         1.000000      1.000000
# 25%       742.000000      1.000000         1.000000      1.000000
# 50%      1186.000000      2.000000         2.000000      2.000000
# 75%      2042.750000      2.000000         2.000000      2.000000
# max     11556.000000      9.000000         9.000000      9.000000

# %% [markdown]
# Từ bảng trên, ta có thể phân chia doanh thu thành 4 hạng:
# - Hạng A: doanh thu trên 2042
# - Hạng B: doanh thu từ 1186 đến 2042
# - Hạng C: doanh thu từ 742 đến 1186
# - Hạng D: dưới 7742

# %%
items_revenue['Revenue_tier'] = items_revenue.apply(lambda x: 'A' if (x['total_revenue'] > 2042) 
                                   else ('B' if (x['total_revenue'] > 1186 and x['total_revenue'] <= 2042) 
                                         else ('C' if (x['total_revenue'] > 742 and x['total_revenue'] <= 1186) 
                                               else 'D')), axis = 1)

# %%
items_revenue
# Out:
#                                               total_revenue  total_orders  \
# Brand            Product
# !lMifo~0~N65rM}2 skyK-date0.237469692167954          2715.0             3
# #B_-`aDe`}CVt'!A 18-`lease0.952310074301681           478.0             1
#                  202rvideo0.0198947312483128          392.0             1
#                  6layenter0.832904875099387          1986.0             3
#                  a-cPrants0.941652415797535          1384.0             2
# ...                                                     ...           ...
# ze\yQP9Ju,s(O|>] zel`video0.809705577564763           332.0             1
#                  zelkvideo0.542849205536647          1052.0             2
#                  zeloalbum0.673018009367897          3234.0             3
# Ét2:1))2]qB2`9;^ etua-baby0.472156023137423          1048.0             2
#                  etujation0.0817298363167827         1233.0             1
#
# ...

# %%
items_revenue.reset_index(level=0)
items_revenue.reset_index(inplace=True)

# %%
items_revenue
# Out:
#                   Brand                      Product  total_revenue  \
# 0      !lMifo~0~N65rM}2   skyK-date0.237469692167954         2715.0
# 1      #B_-`aDe`}CVt'!A   18-`lease0.952310074301681          478.0
# 2      #B_-`aDe`}CVt'!A  202rvideo0.0198947312483128          392.0
# 3      #B_-`aDe`}CVt'!A   6layenter0.832904875099387         1986.0
# 4      #B_-`aDe`}CVt'!A   a-cPrants0.941652415797535         1384.0
# ...                 ...                          ...            ...
# 13537  ze\yQP9Ju,s(O|>]   zel`video0.809705577564763          332.0
# 13538  ze\yQP9Ju,s(O|>]   zelkvideo0.542849205536647         1052.0
# 13539  ze\yQP9Ju,s(O|>]   zeloalbum0.673018009367897         3234.0
# 13540  Ét2:1))2]qB2`9;^   etua-baby0.472156023137423         1048.0
# 13541  Ét2:1))2]qB2`9;^  etujation0.0817298363167827         1233.0
#
#        total_orders  total_customers  total_items Revenue_tier
# 0                 3                3            3            A
# ...

# %%
items_traffic = traffic.groupby(['Product','Brand']).agg(users=('users','sum'),uniquePageviews = ('uniquePageviews','sum'),pageviews = ('pageviews','sum'))

# %%
items_traffic
# Out:
#                                                users  uniquePageviews  \
# Product                     Brand
# 007Jlease0.316606245376631  WaQqK)2JxI(=dac=  1585.0           1643.4
# 007Ywatch0.906707330424838  MouDd/fn,XEARhBp   958.6            975.6
# 017Vorial0.336819995225967  do"hq2Gv(1b#'qX=   166.6            170.2
# 017Ylease0.197057924319041  do"hq2Gv(1b#'qX=  1074.6           1088.6
# 03-Hvideo0.644617973027599  ChbB`+|eEUvC7i;$   526.0            540.4
# ...                                              ...              ...
# zozQation0.0106886180391892 ZofpjB"<UT3{Atib  1129.8           1171.0
# zoz[lease0.281797356811899  PGtI5''D,R;?z94@   378.4            379.6
# zozl-info0.445888607941033  ZofpjB"<UT3{Atib   268.0            272.8
# zseFtream0.740893188572541  ZshVf>1bM}0lEEbH    33.6             34.2
# zucKction0.211927037343636  Ac8IJsKH,4xtY.Tk   941.2            965.0
#
#                                               pageviews
# Product                     Brand
# ...

# %%
items_traffic.describe()
# Out:
#                users  uniquePageviews      pageviews
# count   17889.000000     17889.000000   17889.000000
# mean     1395.496048      1434.260596    1592.936453
# std      3352.450235      3490.933361    4412.133767
# min         0.200000         0.200000       0.400000
# 25%       329.000000       334.800000     358.800000
# 50%       624.000000       635.800000     683.600000
# 75%      1351.400000      1387.200000    1499.800000
# max    215222.600000    221108.400000  232177.000000

# %%
items_traffic['Traffic_tier'] = items_traffic.apply(lambda x: 'A' if (x['pageviews'] > 1499) 
                                   else ('B' if (x['pageviews'] > 683 and x['pageviews'] <= 1499) 
                                         else ('C' if (x['pageviews'] > 358 and x['pageviews'] <= 683) 
                                               else 'D')), axis = 1)

# %%
items_traffic.reset_index(level=0)
items_traffic.reset_index(inplace=True)
items_traffic
# Out:
#                            Product             Brand   users  uniquePageviews  \
# 0       007Jlease0.316606245376631  WaQqK)2JxI(=dac=  1585.0           1643.4
# 1       007Ywatch0.906707330424838  MouDd/fn,XEARhBp   958.6            975.6
# 2       017Vorial0.336819995225967  do"hq2Gv(1b#'qX=   166.6            170.2
# 3       017Ylease0.197057924319041  do"hq2Gv(1b#'qX=  1074.6           1088.6
# 4       03-Hvideo0.644617973027599  ChbB`+|eEUvC7i;$   526.0            540.4
# ...                            ...               ...     ...              ...
# 17884  zozQation0.0106886180391892  ZofpjB"<UT3{Atib  1129.8           1171.0
# 17885   zoz[lease0.281797356811899  PGtI5''D,R;?z94@   378.4            379.6
# 17886   zozl-info0.445888607941033  ZofpjB"<UT3{Atib   268.0            272.8
# 17887   zseFtream0.740893188572541  ZshVf>1bM}0lEEbH    33.6             34.2
# 17888   zucKction0.211927037343636  Ac8IJsKH,4xtY.Tk   941.2            965.0
#
#        pageviews Traffic_tier
# ...

# %%
items_traffic.merge(items_revenue,left_on = ['Product','Brand'],right_on=['Product','Brand'],how = 'inner').sort_values(['pageviews','total_revenue'],ascending=False)
# Out:
#                           Product             Brand     users  \
# 8941   porQlease0.507911745358356  Ac8IJsKH,4xtY.Tk  155640.0
# 9088   pumMvideo0.837931992780922  PU]vXmX9fgf$xf!/   47779.6
# 1726   besfeek-50.280274313298435  BajeQM&IzKX.a8&_   53508.2
# 9549   rogLrecap0.644396392507623  LaX{ty9j_zZdD-\`   52381.2
# 5030   jefXaunch0.410067394635876  Stc\9>Cqq;Rn&/|F   43667.4
# ...                           ...               ...       ...
# 12318   yunsement0.44148099082229  Yu%jaXeE/8L$d$yX       0.2
# 9263   recPeator0.470956776867346  OlDe}#G)yIt'+Bc3       0.2
# 11185  tisetream0.262717438134904  Tir72~+xaqy!(G\-       0.4
# 1958   bobK-news0.573637665518942  Ac8IJsKH,4xtY.Tk       0.2
# 1152   ariDcle-20.188973495512866  Ar0eK=K&2^(."ab~       0.2
#
#        uniquePageviews  pageviews Traffic_tier  total_revenue  total_orders  \
# 8941          156789.4   170599.0            A         2714.0             2
# ...

# %%
items_traffic.merge(items_revenue,left_on = ['Product','Brand'],right_on=['Product','Brand'],how = 'inner').sort_values(['total_revenue','pageviews'],ascending=False)
# Out:
#                            Product             Brand   users  uniquePageviews  \
# 4689    hypsrview0.321288570724117  Il^(xPdB:S`#irqz   524.2            539.8
# 9308    reeelease0.452821711209563  Relp\+KJ?D,cWw0P   257.8            259.2
# 1279    audE-info0.884915261087885  Ac8IJsKH,4xtY.Tk  1086.4           1110.8
# 5637     kinv-news0.29905739542661  DiCo4(99zZ<nkafj   673.8            694.8
# 12220   ymc_orson0.319251813809483  YMbpE$ev3qMx-h*E   198.4            203.2
# ...                            ...               ...     ...              ...
# 160     2g-aation0.859210237517232  Bedz04LN6g4NY{R5   254.8            257.0
# 3993     g-hxrowns0.35584537222102  Br0Aza@`0k<LPOVi  2808.0           2831.6
# 5863    legX-info0.422268138697415  Levk)A7u]J|c_tFD  1258.2           1275.2
# 11531  umaZction0.0701712715774042  Lo:}7^:YFSc4xYIs   446.8            453.4
# 11914   wacNkbook0.849290713312118  Wae3Jy6[wA3Y#k7h   694.0            709.6
#
# ...

# %%
tierlist = items_revenue.merge(items_traffic,left_on = ['Product','Brand'],right_on=['Product','Brand'],how = 'inner').sort_values(['total_revenue','pageviews'],ascending=False)

# %%
#Loại bỏ 1 số cột không cần thiết
tierlist = tierlist[['Brand','Product','total_revenue','pageviews','Revenue_tier','Traffic_tier']]

# %%
tierlist
# Out:
#                   Brand                      Product  total_revenue  \
# 4416   Il^(xPdB:S`#irqz   hypsrview0.321288570724117        11556.0
# 8983   Relp\+KJ?D,cWw0P   reeelease0.452821711209563         9205.0
# 241    Ac8IJsKH,4xtY.Tk   audE-info0.884915261087885         8428.0
# 2908   DiCo4(99zZ<nkafj    kinv-news0.29905739542661         7980.0
# 11458  YMbpE$ev3qMx-h*E   ymc_orson0.319251813809483         7794.0
# ...                 ...                          ...            ...
# 1835   Bedz04LN6g4NY{R5   2g-aation0.859210237517232           72.0
# 2042   Br0Aza@`0k<LPOVi    g-hxrowns0.35584537222102           69.0
# 5384   Levk)A7u]J|c_tFD   legX-info0.422268138697415           63.0
# 5629   Lo:}7^:YFSc4xYIs  umaZction0.0701712715774042           60.0
# 11334  Wae3Jy6[wA3Y#k7h   wacNkbook0.849290713312118           46.0
#
#        pageviews Revenue_tier Traffic_tier
# 4416       587.0            A            C
# 8983       281.8            A            D
# ...

# %%
#Lọc ra những sản phẩm có doanh thu cao và pageview cao
tierlist[(tierlist['Revenue_tier'] == 'A') & (tierlist['Traffic_tier'] == 'A')]
# Out:
#                   Brand                      Product  total_revenue  \
# 9226   Sa?9zXUH5iJbuE'S    samLement0.78565851365938         7518.0
# 4989   Ka>n{\}.q.~P&*Ao   takgeveal0.557457939403364         7049.0
# 6485   MouDd/fn,XEARhBp   stupponyo0.211329698054268         6954.0
# 8622   PoAqnL=>P9Qb"ZUa   poryn-9920.309751616966229         6815.0
# 8889   Relp\+KJ?D,cWw0P   bbcF-date0.977769785530841         6815.0
# ...                 ...                          ...            ...
# 5903   MaYv(\vK4F{`#->J   mar[-ross0.991907683967348         2056.0
# 10354  ThgQNp?BtjmQ3c&>  the`-info0.0577482614251683         2055.0
# 1261   Ap!FulqmT[82a2/E   appvrumor0.214784842132191         2050.0
# 4082   Gu5O-Ixr@HB!y+N?   gucm-info0.775902824990171         2048.0
# 5060   Ke%(`9SH"OqjcGPm   kevNailer0.761374062672084         2044.0
#
#        pageviews Revenue_tier Traffic_tier
# 9226      1590.0            A            A
# 4989      8596.2            A            A
# ...

# %% [markdown]
# ## 3. Có những phân khúc khách hàng nào?

# %%
cus_data = data.groupby(["CustomerID","FirstName", "LastName","Country","Birthday","DateJoined","Newsletter"]).\
                            agg(total_expenditures = ('SellPrice','sum')).\
                            reset_index()

# %%
cus_data
# Out:
#      CustomerID              FirstName                LastName  \
# 0           0.0     V0.296680287495188      L0.104646531512644
# 1           1.0     D0.793097101838541    Law0.141693355411763
# 2           2.0   Ker0.141418247925814     Ng0.753960335680345
# 3           3.0   Fik0.950054552966336      F0.590961171612745
# 4           4.0  Iona0.294287981536498   Ison0.826191754811968
# ..          ...                    ...                     ...
# 765       765.0    Ya0.945566148422846     Lo0.214781069325519
# 766       766.0   Yoo0.331072249620266    Low0.870500054610635
# 767       767.0    Za0.957577858135873  Thoma0.729674423009536
# 768       768.0     Y0.286774649994125   Aung0.752567424443609
# 769       769.0    Yu0.868816854574661   Tuck0.670377392941702
#
#                  Country   Birthday DateJoined Newsletter  total_expenditures
# 0            FR - France 1968-02-03 2015-12-18          N             32997.0
# ...

# %%
from datetime import date

today = date.today()

# tính tuổi
cus_data['Age'] = range(len(cus_data['Birthday']))
for i in range(len(cus_data['Birthday'])):
    cus_data['Age'][i] = today.year - cus_data['Birthday'][i].year

# tính số năm trở thành thành viên
cus_data['Loyalty'] = range(len(cus_data['DateJoined']))
for i in range(len(cus_data['DateJoined'])):
    cus_data['Loyalty'][i] = today.year - cus_data['DateJoined'][i].year

# %%
cus_data
# Out:
#      CustomerID              FirstName                LastName  \
# 0           0.0     V0.296680287495188      L0.104646531512644
# 1           1.0     D0.793097101838541    Law0.141693355411763
# 2           2.0   Ker0.141418247925814     Ng0.753960335680345
# 3           3.0   Fik0.950054552966336      F0.590961171612745
# 4           4.0  Iona0.294287981536498   Ison0.826191754811968
# ..          ...                    ...                     ...
# 765       765.0    Ya0.945566148422846     Lo0.214781069325519
# 766       766.0   Yoo0.331072249620266    Low0.870500054610635
# 767       767.0    Za0.957577858135873  Thoma0.729674423009536
# 768       768.0     Y0.286774649994125   Aung0.752567424443609
# 769       769.0    Yu0.868816854574661   Tuck0.670377392941702
#
#                  Country   Birthday DateJoined Newsletter  total_expenditures  \
# 0            FR - France 1968-02-03 2015-12-18          N             32997.0
# ...

# %%
customer = cus_data.merge(customer_info[['ID','Gender']],how='inner',left_on='CustomerID', right_on='ID')

# %%
customer
# Out:
#      CustomerID              FirstName                LastName  \
# 0           0.0     V0.296680287495188      L0.104646531512644
# 1           1.0     D0.793097101838541    Law0.141693355411763
# 2           2.0   Ker0.141418247925814     Ng0.753960335680345
# 3           3.0   Fik0.950054552966336      F0.590961171612745
# 4           4.0  Iona0.294287981536498   Ison0.826191754811968
# ..          ...                    ...                     ...
# 765       765.0    Ya0.945566148422846     Lo0.214781069325519
# 766       766.0   Yoo0.331072249620266    Low0.870500054610635
# 767       767.0    Za0.957577858135873  Thoma0.729674423009536
# 768       768.0     Y0.286774649994125   Aung0.752567424443609
# 769       769.0    Yu0.868816854574661   Tuck0.670377392941702
#
#                  Country   Birthday DateJoined Newsletter  total_expenditures  \
# 0            FR - France 1968-02-03 2015-12-18          N             32997.0
# ...

# %%
customer.drop('ID', inplace=True, axis=1)
customer
# Out:
#      CustomerID              FirstName                LastName  \
# 0           0.0     V0.296680287495188      L0.104646531512644
# 1           1.0     D0.793097101838541    Law0.141693355411763
# 2           2.0   Ker0.141418247925814     Ng0.753960335680345
# 3           3.0   Fik0.950054552966336      F0.590961171612745
# 4           4.0  Iona0.294287981536498   Ison0.826191754811968
# ..          ...                    ...                     ...
# 765       765.0    Ya0.945566148422846     Lo0.214781069325519
# 766       766.0   Yoo0.331072249620266    Low0.870500054610635
# 767       767.0    Za0.957577858135873  Thoma0.729674423009536
# 768       768.0     Y0.286774649994125   Aung0.752567424443609
# 769       769.0    Yu0.868816854574661   Tuck0.670377392941702
#
#                  Country   Birthday DateJoined Newsletter  total_expenditures  \
# 0            FR - France 1968-02-03 2015-12-18          N             32997.0
# ...

# %%
df = customer[['total_expenditures', 'Age']]
df
# Out:
#      total_expenditures  Age
# 0               32997.0   54
# 1               34948.0   13
# 2               17879.0   32
# 3               14603.0   48
# 4               37029.0   41
# ..                  ...  ...
# 765             29538.0   33
# 766              5331.0   57
# 767             45470.0   42
# 768             35462.0   42
# 769             24568.0   32
#
# [770 rows x 2 columns]

# %% [markdown]
# ### Build Model

# %%
from kneed import KneeLocator
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# %%
scaler = StandardScaler()
scaled_features = scaler.fit_transform(df)

# %%
kmeans_kwargs = {
"init": "random",
"n_init": 10,
"max_iter": 300,
"random_state": 42,
}

# A list holds the SSE values for each k
sse = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, **kmeans_kwargs)
    kmeans.fit(scaled_features)
    sse.append(kmeans.inertia_)

# %%
fig, ax = plt.subplots(figsize=(12, 6))

ax.plot(range(1, 11), sse)

spines = ['top', 'right']
for s in spines:
    ax.spines[s].set_visible(False) 
    
    
ax.xaxis.grid(linestyle='dashed')
plt.xticks(range(1, 11))
plt.xlabel("Number of Clusters")
plt.ylabel("SSE")
plt.show()

# %%
kl = KneeLocator(range(1, 11), sse, curve='convex', direction='decreasing')
kl.elbow
# Out:
# 4

# %%
# A list holds the silhouette coefficients for each k
silhouette_coefficients = []

# Notice you start at 2 clusters for silhouette coefficient
for k in range(2, 11):
    kmeans = KMeans(n_clusters=k, **kmeans_kwargs)
    kmeans.fit(scaled_features)
    score = silhouette_score(scaled_features, kmeans.labels_)
    silhouette_coefficients.append(score)

# %%
#plt.style.use("fivethirtyeight")
fig, ax = plt.subplots(figsize=(12, 6))

ax.plot(range(2, 11), silhouette_coefficients)

spines = ['top', 'right']
for s in spines:
    ax.spines[s].set_visible(False) 
    
    
ax.xaxis.grid(linestyle='dashed')
plt.xticks(range(2, 11))

plt.xticks(range(2, 11))
plt.xlabel("Number of Clusters")
plt.ylabel("Silhouette Coefficient")
plt.show()

# %%
nclusters = 4
kmeans = KMeans(n_clusters=nclusters, random_state=0).fit(df)

# %%
df["Cluster Labels"] = kmeans.labels_

# %%
df['Cluster Labels'].value_counts()
# Out:
# 0    226
# 1    215
# 2    205
# 3    124
# Name: Cluster Labels, dtype: int64

# %%
cus_data["Cluster Labels"] = kmeans.labels_

# %%
cus_data[cus_data["Cluster Labels"] == 0]
# Out:
#      CustomerID              FirstName                LastName        Country  \
# 2           2.0   Ker0.141418247925814     Ng0.753960335680345    FR - France
# 6           6.0    Ad0.410135716954602    Tan0.662463855720801  GER - Germany
# 8           8.0     S0.892783416837388    WEN0.271074390106408    FR - France
# 11         11.0     N0.584326642863632     Sy0.115997440873676     IT - Italy
# 15         15.0  Wang0.848812851699671    Ruig0.58432545739683  GER - Germany
# ..          ...                    ...                     ...            ...
# 754       754.0   Yoo0.202121132538464    Goh0.375737577987716  GER - Germany
# 756       756.0   Wu0.0113344610441295    Ang0.128149197304773  GER - Germany
# 762       762.0   Zam0.813904666031585  Junic0.545285600996212  GER - Germany
# 763       763.0    Yu0.303180134749509      S0.756980561256767  GER - Germany
# 769       769.0    Yu0.868816854574661   Tuck0.670377392941702  GER - Germany
#
# ...

# %%
cus_data[cus_data["Cluster Labels"] == 1]
# Out:
#      CustomerID               FirstName                LastName  \
# 0           0.0      V0.296680287495188      L0.104646531512644
# 1           1.0      D0.793097101838541    Law0.141693355411763
# 4           4.0   Iona0.294287981536498   Ison0.826191754811968
# 5           5.0  Celin0.498684223052738    Tio0.597043135639238
# 9           9.0   Chok0.637930969851357     SW0.984189910495377
# ..          ...                     ...                     ...
# 755       755.0  Wee K0.723843648615867    Ang0.128149197304773
# 757       757.0   Yvon0.123331623956968  Cheah0.068060632270693
# 758       758.0      Y0.044525328124793    Ad0.0973592950295998
# 765       765.0     Ya0.945566148422846     Lo0.214781069325519
# 768       768.0      Y0.286774649994125   Aung0.752567424443609
#
#                  Country   Birthday DateJoined Newsletter  total_expenditures  \
# 0            FR - France 1968-02-03 2015-12-18          N             32997.0
# ...

# %%
cus_data[cus_data["Cluster Labels"] == 2]
# Out:
#      CustomerID              FirstName                LastName  \
# 3           3.0   Fik0.950054552966336      F0.590961171612745
# 7           7.0    Ev0.291189764697797     Kh0.766529502176661
# 13         13.0    Li0.816138101924376      C0.844976286057262
# 14         14.0   Ana0.456234761724834   Muan0.860501018032884
# 16         16.0  Dere0.852029962983164      S0.756980561256767
# ..          ...                    ...                     ...
# 749       749.0    Wi0.410749035640529    Lim0.185633050851678
# 753       753.0  Wi Li0.94046792206097  Chng0.0927496047935558
# 759       759.0   Yoo0.202121132538464    Goh0.375737577987716
# 764       764.0  Yuni0.412862497006326    C0.00700087328826338
# 766       766.0   Yoo0.331072249620266    Low0.870500054610635
#
#                  Country   Birthday DateJoined Newsletter  total_expenditures  \
# 3    UK - United Kingdom 1974-07-24 2015-12-22          N             14603.0
# ...

# %%
cus_data[cus_data["Cluster Labels"] == 3]
# Out:
#      CustomerID              FirstName                LastName  \
# 10         10.0  Bill0.944762168333042      W0.775201627445077
# 28         28.0      K0.32016897315613       Ra0.2919844052243
# 29         29.0   Uma0.992924442326397   Harj0.392705673735006
# 32         32.0     S0.280194605314208   Jusm0.413899149274186
# 43         43.0  Jann0.718621382110817   De G0.552809006474718
# ..          ...                    ...                     ...
# 743       743.0    Yu0.504450706950172      Q0.484946567694281
# 751       751.0     V0.296680287495188    Pan0.346033355426464
# 760       760.0    We0.401622991634416     Fo0.730822068803465
# 761       761.0   Yan0.101931673023518    Chu0.306978358145085
# 767       767.0    Za0.957577858135873  Thoma0.729674423009536
#
#                  Country   Birthday DateJoined Newsletter  total_expenditures  \
# 10         GER - Germany 1981-06-16 2016-01-04          N             41584.0
# ...

# %%
cus_data['Cluster Labels'].value_counts()
# Out:
# 0    226
# 1    215
# 2    205
# 3    124
# Name: Cluster Labels, dtype: int64
